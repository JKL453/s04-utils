# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [9]</a>'.</span>

# %%
# auto-reload modules when they have changed
# %reload_ext autoreload
# %autoreload 2

# %%
from modules.analyze.blob_detection import BlobDetector
from modules.load import image
from config import config as cfg

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


from tabulate import tabulate

# %%
SOURCE_IMAGE_PATH = '/Users/kappel/Messungen/Setup04/JaKa/post_hack/23_07_06/control-77K-buffer+glycerol-vitrified/10uW/images/img_control_NaP_100mM_ph7dot5_Glycerol10_10uW_77K_circpol_20um_001.img'

# %%
# Parameters
SOURCE_IMAGE_PATH = "/Users/kappel/Messungen/Setup04/JaKa/post_hack/23_08_09/77K-33nM-eGFP-vitrified/20uW/images/img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img"

# %%
# Load image
im = image.load_from_path(SOURCE_IMAGE_PATH)

# %%
image = im.data['preview']
print(type(image))
print(type(image[0][0]))

im.preview()

min_intensity = np.amin(image)
max_intensity = np.amax(image)
median_intensity = np.median(image)

# Print the different intensity values
print('Minimum intensity: ', min_intensity)
print('Maximum intensity: ', max_intensity)
print('Median intensity:  ', int(median_intensity))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.int64'>
# Data (arrays) in image file:
#   - preview : (128, 128), int64
#
#
# Minimum intensity:  0
# Maximum intensity:  83
# Median intensity:   5

# %%
# Create histogram of grayscale values from image

# %%
# Initialize blob detector
bd = BlobDetector(input_image=image, blob_type='log')

# Detect blobs
blobs = bd.detect_blobs(min_sigma=3, max_sigma=4, num_sigma=10, threshold=0.1);

# Plot blobs on image
bd.plot_blobs(blobs, vmin=np.median(image))

# %%
print(blobs)
blob_data = blobs
# Out:
# [[127.          37.           3.        ]
#  [ 24.          21.           3.        ]
#  [114.          87.           3.        ]
#  [ 96.          66.           3.        ]
#  [127.          25.           3.        ]
#  [ 11.         104.           3.        ]
#  [ 19.          49.           3.        ]
#  [ 64.           0.           3.        ]
#  [115.          19.           3.        ]
#  [  5.          15.           3.        ]
#  [ 72.          26.           3.        ]
#  [ 86.         116.           3.        ]
#  [ 78.         104.           3.        ]
#  [ 91.           8.           3.        ]
#  [ 64.         127.           3.        ]
#  [110.          53.           3.        ]
#  [ 25.         108.           3.        ]
#  [123.          76.           3.        ]
#  [ 35.          98.           3.        ]
#  [ 96.           3.           3.        ]
#  [116.          68.           3.        ]
#  [ 76.          60.           3.        ]
#  [ 50.          24.           3.        ]
#  [126.          59.           3.        ]
#  [102.          43.           3.        ]
#  [ 16.           5.           3.        ]
#  [ 92.          50.           3.        ]
#  [ 71.         121.           3.        ]
#  [ 52.          19.           3.        ]
#  [ 41.         115.           3.        ]
#  [  8.         127.           3.        ]
#  [ 65.          91.           3.        ]
#  [ 64.         107.           3.        ]
#  [125.          50.           3.        ]
#  [103.         127.           4.        ]
#  [112.         120.           3.        ]
#  [ 84.          29.           3.        ]
#  [ 60.         100.           3.        ]
#  [105.          31.           3.        ]
#  [ 34.          70.           3.        ]
#  [ 69.          84.           3.        ]
#  [ 76.          46.           3.        ]
#  [ 94.          17.           3.        ]
#  [117.         103.           3.        ]
#  [ 96.         122.           3.        ]
#  [ 42.           5.           3.        ]
#  [107.           0.           3.        ]
#  [ 70.          11.           3.        ]
#  [ 23.          74.           3.        ]
#  [104.          18.           3.        ]
#  [ 40.          31.           3.        ]
#  [ 62.          31.           3.        ]
#  [ 55.          92.           3.        ]
#  [  9.          71.           3.22222222]
#  [ 25.          32.           3.        ]
#  [ 24.         125.           3.        ]
#  [  3.          55.           3.        ]
#  [ 53.          78.           3.        ]
#  [ 62.          47.           3.        ]
#  [ 33.          52.           3.        ]
#  [106.          75.           3.        ]
#  [104.          90.           3.        ]
#  [ 12.         116.           3.        ]
#  [ 43.          81.           3.        ]
#  [ 97.          56.           3.        ]
#  [ 50.          39.           3.        ]
#  [ 61.          72.           3.        ]
#  [ 71.          96.           3.        ]
#  [ 37.          40.           3.        ]
#  [ 47.         118.           3.        ]
#  [ 11.           0.           4.        ]
#  [ 39.          11.           3.        ]
#  [ 23.          63.           3.        ]
#  [ 89.          73.           3.        ]
#  [102.         109.           3.        ]
#  [ 26.           0.           3.        ]
#  [ 48.          99.           3.        ]
#  [ 89.          92.           3.        ]]

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
blobs_log = blob_data
blobs = []

image_array = im.data['APD1'] + im.data['APD2']

for blob in blobs_log:
    # Get blob coordinates and radius
    y, x, r = blob

    # Extract blob pixels from original image
    blob_pixels = image_array[int(y - r):int(y + r), int(x - r):int(x + r)]

    if blob_pixels.shape[0] == blob_pixels.shape[1]: 
        blobs.append(blob_pixels)
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kappel/Documents/Programming/python-projects/s04utils/papermill-test-img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img.ipynb Zelle 11 line 4
#       <a href='vscode-notebook-cell:/Users/kappel/Documents/Programming/python-projects/s04utils/papermill-test-img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> blobs_log = blob_data
#       <a href='vscode-notebook-cell:/Users/kappel/Documents/Programming/python-projects/s04utils/papermill-test-img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> blobs = []
# ----> <a href='vscode-notebook-cell:/Users/kappel/Documents/Programming/python-projects/s04utils/papermill-test-img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> image_array = im.data['APD1'] + im.data['APD2']
#       <a href='vscode-notebook-cell:/Users/kappel/Documents/Programming/python-projects/s04utils/papermill-test-img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> for blob in blobs_log:
#       <a href='vscode-notebook-cell:/Users/kappel/Documents/Programming/python-projects/s04utils/papermill-test-img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a>     # Get blob coordinates and radius
#       <a href='vscode-notebook-cell:/Users/kappel/Documents/Programming/python-projects/s04utils/papermill-test-img_eGFP_33nm_NaP_100mM_ph7dot5_Treh7dot5_20uW_77K_circpol_003.img.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>     y, x, r = blob
#
# KeyError: 'APD1'

# %%
# Create list to store average intensities
avg_intensities = []
max_intensities = []

# Loop over blobs and plot in subplots
for i, blob in enumerate(blobs):
    # Calculate average intensity
    avg_intensity = np.mean(blob)

    # Calculate max intensity
    max_intensity = np.max(blob)

    avg_intensities.append(avg_intensity)
    max_intensities.append(max_intensity)

# Calculate histogram parameters
r_avg_intensities = [round(intensity) for intensity in avg_intensities]
r_max_intensities = [round(intensity) for intensity in max_intensities]

print(r_avg_intensities)
print(r_max_intensities)

# %%
blob_data = []
for i, blob in enumerate(blobs):
    blob_data.append(['blob_{}'.format(i+1), r_avg_intensities[i], r_max_intensities[i]])

print(blob_data)

# Print the table using the tabulate function
print(tabulate(blob_data, headers=['ID', 'Avg.\nintensity', 'Max.\nintensity'], tablefmt='rst'))
