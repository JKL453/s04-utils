# %%
from modules.analyze.blob_detection import BlobDetector
from modules.visualize import plot
from modules.load import image
from config import config as cfg

# %%
# Load image
im = image.load_from_path("/Users/kappel/Desktop/img_test_data_two_detectors_005.img")

# %%
im.preview()
# Out:
# Data (arrays) in image file:
#   - preview : (50, 50), int64
#   -    APD1 : (50, 50), int64
#   -    APD2 : (50, 50), int64

# %%
image_detector0 = im.data['APD1']
image_detector1 = im.data['APD2']

# %%
plot.image(im, de)
