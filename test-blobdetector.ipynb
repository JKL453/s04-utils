# %%
# auto-reload modules when they have changed
# %reload_ext autoreload
# %autoreload 2

# %%
from modules.analyze.blob_detection import BlobDetector
from modules.load import image
from config import config as cfg

# %%
# Load image
im = image.load_from_path(cfg.image_FIDA_path)

# Initialize blob detector
bd = BlobDetector(input_image=im, blob_type='log')
# Out:
# Warning: No channel specified, using sum of channel_0 and channel_1.

# %%
# Detect blobs
blobs = bd.detect_blobs(min_sigma=3, max_sigma=5, num_sigma=10, threshold=0.01);

# TODO: Plot blobs on image
bd.plot_blobs(blobs)

# %%
bd.compare_blob_methods(min_sigma=3, max_sigma=5, num_sigma=10, threshold=0.01)
